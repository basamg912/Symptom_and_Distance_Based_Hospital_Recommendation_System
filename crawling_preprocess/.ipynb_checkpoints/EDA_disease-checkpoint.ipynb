# %%
import os
import json
import pandas as pd
from collections import defaultdict
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

ans = []
ques = []
def read_json(folder_path):
    temp = []
    for root, dirs, files in os.walk(folder_path):
        for file in sorted(files):
            if file.endswith(".json"):
                full_path = os.path.join(root, file)
                with open(full_path, 'r', encoding='utf-8') as f:
                    data = json.load(f)
                    temp.append(data)
    return temp

ques = read_json("EDA/질문")
ans = read_json("EDA/답변")

# %%
# 질병별 그룹핑
ques_by_disease = defaultdict(list)
ans_by_disease = defaultdict(list)

for q in ques:
    d = q.get("disease_name", {}).get("kor")
    ques_by_disease[d].append(q)

for a in ans:
    d = a.get("disease_name", {}).get("kor")
    ans_by_disease[d].append(a)

merged_data = []

for disease in ques_by_disease:
    q_list = ques_by_disease[disease]
    a_list = ans_by_disease.get(disease, [])
    
    # zip 사용, 수가 다르면 짧은 쪽 기준
    for q, a in zip(q_list, a_list):
        merged_data.append({
            "question_id": q.get("fileName"),
            "answer_id": a.get("fileName"),
            "disease": disease,
            "disease_category": q.get("disease_category"),
            "intention": q.get("intention"),
            "question_text": q.get("question"),
            "answer_intro": a.get("answer", {}).get("intro"),
            "answer_body": a.get("answer", {}).get("body"),
            "answer_conclusion": a.get("answer", {}).get("conclusion")
        })

# %%
df = pd.DataFrame(merged_data)
df
# Out:
#         question_id      answer_id disease disease_category intention  \
# 0      HC-Q-1206458  HC-A-02786821      비듬             피부질환        약물
# 1      HC-Q-1206459  HC-A-02786837      비듬             피부질환        약물
# 2      HC-Q-1206460  HC-A-02786839      비듬             피부질환        약물
# 3      HC-Q-1206461  HC-A-02786852      비듬             피부질환        약물
# 4      HC-Q-1206462  HC-A-02786867      비듬             피부질환        약물
# ...             ...            ...     ...              ...       ...
# 93769  HC-Q-0019373  HC-A-01842029      천식            호흡기질환        정의
# 93770  HC-Q-0019374  HC-A-01842093      천식            호흡기질환        정의
# 93771  HC-Q-0019377  HC-A-01842163      천식            호흡기질환        정의
# 93772  HC-Q-0019378  HC-A-01842208      천식            호흡기질환        정의
# 93773  HC-Q-0019379  HC-A-01842308      천식            호흡기질환        정의
#
#                                            question_text  \
# 0                       비듬을 치료하기 위해 어떤 약물을 사용하는 것이 좋을까요?
# 1                    비듬을 개선시키는데 도움이 되는 약물을 추천해주실 수 있을까요?
# 2                  약물을 사용하여 비듬을 없앨 수 있는 방법이 있는지 알고 싶습니다.
# 3         두피의 각질에 먼지가 묻어서 생긴 비듬을 약물로 어떻게 줄일 수 있는지 알려주세요.
# 4                            비듬을 약물로 치료하는 방법이 있는지 알려주세요.
# ...                                                  ...
# 93769                          천식에 대한 정의와 주요 증상을 알고 싶어요.
# 93770                         천식에 대한 상세한 정의와 특징을 알고 싶어요.
# 93771                            천식이란 어떤 이유로 발생하는 질환인가요?
# 93772                             천식이란 어떤 증상을 보이는 질병인가요?
# 93773  천식의 증상 중에서 목이 간질거리고 숨쉬기가 어려워지는 것이 어떤 의미를 가지는 건가요?
#
#                                             answer_intro  \
# 0                          비듬 치료에는 여러 가지 약물이 사용될 수 있습니다.
# 1      비듬은 주로 지루성 피부염이나 건선과 같은 만성 피부질환 치료에 사용되는 비듬 약물...
# 2              비듬은 피부가 비정상적으로 발생하는 피부염으로, 치료가 가능한 질환입니다.
# 3      비듬은 많은 사람들에게 영향을 미치는 피부 문제입니다. 특히 건성 비듬은 두피에서 ...
# 4      비듬은 피부에 발생하는 각질과 염증으로 인해 발생하는 현상입니다. 비듬이 생기는 주...
# ...                                                  ...
# 93769  천식은 흡입기나 약물 치료를 통해 통제할 수 있는 만성 기도질환입니다. 치료 방법은...
# 93770  천식은 호흡기 질환으로 호흡기와 관련된 기관들을 조절하는 기관 내에서 발생하는 기관...
# 93771  천식 치료에는 여러 가지 방법이 있습니다. 일반적으로 천식은 생활환경에서 유발 요인...
# 93772          천식 치료는 천식 발작을 예방하고 증상을 완화시키는 것이 주요 목표입니다.
# 93773  천식은 알레르기 반응에 의해 발생하는 호흡기 질환입니다. 치료는 증상의 정도와 심각...
#
#                                              answer_body  \
# 0      비듬을 완전히 치료할 수 있는 약물은 없지만, 일부 약물은 비듬을 억제하고 예방하는...
# 1      피록톤 올라민은 대표적인 항진균제로 비듬 치료에 널리 사용되고 있습니다. 또한, 케...
# 2      비듬 치료에 가장 효과적인 약물은 피록톤 올라민, 케토코나졸, 아연 피리티온 및 이...
# 3      비듬 치료를 위한 주요 약물은 프로피온산입니다. 프로피온산은 피부의 각질을 억제하고...
# 4      비듬은 주로 지루한 피부 상태로 인해 발생하는데, 지루성 피부염이 생기는 과정에서 ...
# ...                                                  ...
# 93769  약물 치료에는 효과적인 흡입제, 스테로이드, 류코트리엔 길항제, 알레르기 억제제, ...
# 93770  천식은 주로 알레르기성 호흡기 질환과 같이 유전적인 요인과 환경 요소의 복합적인 작...
# 93771  천식은 만성적인 질병으로 알려져 있지만, 이를 효과적으로 치료하기 위해 약물 요법이...
# 93772  천식 치료의 주요 목표는 기관지 수축을 예방하고 증상을 완화시키는 것입니다. 이를 ...
# 93773  약물 치료는 증상의 종류와 심각성에 따라 선택되는 약물이 달라집니다. 천식 발작이 ...
#
#                                        answer_conclusion
# 0      비듬 치료에는 다양한 약물이 사용되며, 개인의 상태와 사용하는 약물에 따라 적합한 ...
# 1      하지만 약물을 선택할 때는 전문가의 지시에 따라 사용되어야 합니다. 피부과 전문의는...
# 2      비듬 치료에는 다양한 약물이 사용되며, 개인의 피부 상태와 선호도에 맞게 사용되어야...
# 3      비듬 치료를 위해 다양한 약물이 존재하지만, 피르벤산과 프로피온산의 조합이 일반적으...
# 4      비듬은 비특이적인 현상이므로 완전한 치료를 위해서는 적절한 치료가 필요합니다. 비듬...
# ...                                                  ...
# 93769  천식 치료는 약물 치료 외에도 생활습관 개선, 알레르기 관리 등을 통해 환자의 삶의...
# 93770  천식은 알레르기성 호흡기 질환과 같이 유전적 요인과 알레르기원 회피, 호흡기 증상 ...
# 93771  천식 환자는 일상 생활에서 항상 주의를 기울여야 합니다. 담배 연기나 먼지가 많은 ...
# 93772  천식 치료는 천식 발작을 예방하고 증상을 완화시키는 것이 목표입니다. 증상의 심각성...
# 93773  천식은 다양한 치료법을 통해 증상을 완화할 수 있는 질환입니다. 약물 치료와 약물 ...
#
# [93774 rows x 9 columns]

# %%
font_path = "/System/Library/Fonts/Supplemental/AppleGothic.ttf"

df['disease'].value_counts().plot(kind='bar',title='질병별 진문 수')
fontprop = fm.FontProperties(fname=font_path, size=12)
plt.rc('font', family=fontprop.get_name())
plt.xticks(rotation=45, ha='right',fontsize=5)
plt.xlabel('질병명')
# Out:
# Text(0.5, 0, '질병명')

# %%
for category in df['disease_category'].dropna().unique():
    subset = df[df['disease_category']==category]
    plt.figure(figsize=(8,4))
    subset['disease'].value_counts().plot(kind='bar')
    plt.title(f"{category} 내의 Data 분포")
    plt.xticks(rotation=45,ha='right',fontsize=7)
    plt.show()
